# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
import pandas as pd
import numpy as np
from pandas.tseries.offsets import MonthEnd

# %%
copied_path = '/content/drive/My Drive/ATMS_597/Project_4D/KCMI_daily.csv'

# %%
## Opening data, and dropping NaN

#data = pd.read_csv('/content/drive/My Drive/ATMS_597/Project_4D/KCMI_daily.csv', sep=",",comment='"', na_values='   -99.99') #header and skipsrows could be useful for opening new datasets

#df = pd.read_csv('/content/drive/My Drive/ATMS_597/Project_4D/KCMI_daily.csv', error_bad_lines= False)

file = open("/content/drive/My Drive/ATMS_597/Project_4D/KCMI_daily.csv","r")

#Read each line of the file, alternate methods are list(f) and f.readlines()
for line in file:
     print(line, end='')
     #print(line) # which is the difference between this and above's print????
# Aternatives:
#print(list(file))
#print(file.readlines())
    

#Close the file, closing the file after reading and/or writing is a programming best practice.        
file.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#       </tr>
#
#       <tr>
#
#         <td id="L3079" class="blob-num js-line-number" data-line-number="3079"></td>
#
#         <td id="LC3079" class="blob-code blob-code-inner js-file-line">2018-05-28,97,68,11,0.00,</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L3080" class="blob-num js-line-number" data-line-number="3080"></td>
#
#         <td id="LC3080" class="blob-code blob-code-inner js-file-line">2018-05-29,88,71,17,M,</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L3081" class="blob-num js-line-number" data-line-number="3081"></td>
#
#         <td id="LC3081" class="blob-code blob-code-inner js-file-line">2018-05-30,81,72,11,1.17,</td>
#
#       </tr>
#
#       <tr>
#
#         <td id="L3082" class="blob-num js-line-number" data-line-number="3082"></td>
#
#         <td id="LC3082" class="blob-code blob-code-inner js-file-line">2018-05-31,90,68,18,M,</td>
#
#       </tr>
#
#       <tr>
#
# ...

# %%
file
# Out:
# <_io.TextIOWrapper name='/content/drive/My Drive/ATMS_597/Project_4D/KCMI_daily.csv' mode='r' encoding='UTF-8'>
